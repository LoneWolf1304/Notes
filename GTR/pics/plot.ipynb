# %%
using Plots, LaTeXStrings, PythonPlot

# %%
pythonplot()
# Out:
# Plots.PythonPlotBackend()

# %%
V(r) = (-0.4/r) + (1.2/r^2) -(0.4/r^3)
Vn(r) = (-0.4/r) + (1.2/r^2) 
r = LinRange(0.2, 3,1000)
Plots.plot(r, V.(r), label=L"V_{\mathrm{GR}}")
Plots.plot!(r, Vn.(r), label=L"V_{\mathrm{N}}", c="blue", xlabel=L"r", ylabel=L"V(r)", legend=:top)

ylims!(-0.5,3)
Plots.scatter!([0.5503503503503504],[0.8354645701668355
], c="red", label="")
hline!([0], ls=:dash, c="black", label="")
# Out:
# <sys>:0: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# <sys>:0: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# <sys>:0: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# <sys>:0: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
vals = [V(r) for r in LinRange(0.2, 3,1000)]
ind = findall(x->x==maximum(vals), vals)
println(maximum(vals))
println(LinRange(0.2, 3,1000)[126])
# Out:
# 0.8354645701668355
# 0.5503503503503504

# %%
Plots.savefig("potential.pdf")
# Out:
# <sys>:0: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
# "/home/shaggy1304/IISER/IISER_Courses/Notes/GTR/pics/potential.pdf"
